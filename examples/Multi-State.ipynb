# %%
import os
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split


sys.path.insert(0, "/data/keeling/a/jdnied2/c/598/rs-embed/src")
sys.path.insert(0, "/data/keeling/a/jdnied2/c/598/rs-embed/")

from examples.utils_demo import (
    ee_initialize,
    iter_export_points,
    iter_model_vectors,
    load_one_preview_patch,
    point_key,
    point_row_index,
    resolve_preview_group_dirs,
    rings_from_geom_info,
    stretch_rgb,
)
from rs_embed import InputPrepSpec, OutputSpec, PointBuffer, TemporalSpec, export_batch

STATES = ["Minnesota", "South Dakota", "Kansas", 
          "Iowa", "Illinois", "Indiana", 
          "Missouri", "Wisconsin", "Kentucky"]

# Replace your path here
H_CSV = "/data/keeling/a/jdnied2/c/598/rs-embed/dataverse_files/Global_CSV/spam2020V2r0_global_harvested_area/spam2020V2r0_global_H_TA.csv"
Y_CSV = "/data/keeling/a/jdnied2/c/598/rs-embed/dataverse_files/Global_CSV/spam2020V2r0_global_yield/spam2020V2r0_global_Y_TA.csv"
EXPORT_ROOT = Path(os.getenv("DEMO_EXPORT_DIR", "./exports_tile")).expanduser()

SPAM_CROP_COL = os.getenv("SPAM_CROP_COL", "MAIZ_A").upper()
COUNTRY_CODE = os.getenv("SPAM_COUNTRY_CODE", "US").upper()
# LABEL_YEAR = int(os.getenv("SPAM_LABEL_YEAR", "2020"))
MIN_AREA_HA = float(os.getenv("MAIZ_AREA_MIN_HA", "2500"))
# MIN_AREA_HA = float(os.getenv("MAIZ_AREA_MIN_HA", "1000"))

BUFFER_M = int(os.getenv("BUFFER_M", "2000"))

# Select model as needed here
MODEL_LIST = [
    "terrafm",
    "satvision",
    "agrifm",
    "satmae"
]


EMBED_START = os.getenv("EMBED_START", "2019-06-01")
EMBED_END = os.getenv("EMBED_END", "2019-08-31")
TEMPORAL = TemporalSpec.range(EMBED_START, EMBED_END)

TEST_SIZE = float(os.getenv("REG_TEST_SIZE", "0.25"))
MIN_SAMPLES = int(os.getenv("MIN_MODEL_SAMPLES", "30"))

EE_PROJECT = os.getenv("EE_PROJECT")
EE_PROJECT = "cs-598-491115"
print(
    {
        "EXPORT_ROOT": str(EXPORT_ROOT),
        "MODEL_LIST": MODEL_LIST,
        # "LABEL_YEAR": LABEL_YEAR,
        "BUFFER_M": BUFFER_M,
        "TEMPORAL": [EMBED_START, EMBED_END],
    }
)

SAVE_INPUTS = bool(int(os.getenv("SAVE_INPUTS", "1")))
# Out:
# {'EXPORT_ROOT': 'exports_tile', 'MODEL_LIST': ['terrafm', 'satvision', 'agrifm', 'satmae'], 'BUFFER_M': 2000, 'TEMPORAL': ['2019-06-01', '2019-08-31']}

# %%
import ee
out = ee.Initialize(project="cs-598-491115") 
print(out)
# Out:
# None

# %%
# rings_from_geom_info(roi_geom.getInfo())

# %%
def rings_from_geom_info(geom_info: dict):
    gtype = geom_info.get("type")
    coords = geom_info.get("coordinates", [])

    if gtype == "Polygon":
        # coords[0] = exterior boundary; coords[1:] = holes
        return [np.asarray(coords[0], dtype=float)]

    if gtype == "MultiPolygon":
        return [
            np.asarray(poly[0], dtype=float)
            for poly in coords
            if poly and poly[0]
        ]

    if gtype == "LineString":
        return [np.asarray(coords, dtype=float)]

    if gtype == "MultiLineString":
        return [
            np.asarray(line, dtype=float)
            for line in coords
            if line
        ]

    if gtype == "GeometryCollection":
        rings = []
        for geom in geom_info.get("geometries", []):
            rings.extend(rings_from_geom_info(geom))
        return rings

    # Skip anything else instead of crashing
    return []

# %% [markdown]
# <h1> Plot SPAM Maize State Dist. </h1>

# %%
# No subsample - all data
csv_path  = H_CSV
value_name="maize_area_ha"
usecols = ["grid_code", "x", "y", "FIPS0", "ADM1_NAME", "year_data", SPAM_CROP_COL]
table = pd.read_csv(csv_path, usecols=usecols, encoding="utf-8-sig")
table = table.rename(columns={"x": "lon", "y": "lat", SPAM_CROP_COL: value_name})

table["grid_code"] = table["grid_code"].astype(str)
table["FIPS0"] = table["FIPS0"].astype(str).str.upper()
table["ADM1_NAME"] = table["ADM1_NAME"].astype(str)
table["year_data"] = table["year_data"].astype(str)
table[value_name] = pd.to_numeric(table[value_name], errors="coerce")

table_h = table[
    table["FIPS0"].eq(COUNTRY_CODE)
    # & table["year_data"].str.contains(str(LABEL_YEAR), na=False)
]


csv_path  = Y_CSV
value_name="label"
usecols = ["grid_code", "x", "y", "FIPS0", "ADM1_NAME", "year_data", SPAM_CROP_COL]
table = pd.read_csv(csv_path, usecols=usecols, encoding="utf-8-sig")
table = table.rename(columns={"x": "lon", "y": "lat", SPAM_CROP_COL: value_name})

table["grid_code"] = table["grid_code"].astype(str)
table["FIPS0"] = table["FIPS0"].astype(str).str.upper()
table["ADM1_NAME"] = table["ADM1_NAME"].astype(str)
table["year_data"] = table["year_data"].astype(str)
table[value_name] = pd.to_numeric(table[value_name], errors="coerce")

table_y = table[
    table["FIPS0"].eq(COUNTRY_CODE)
    # & table["year_data"].str.contains(str(LABEL_YEAR), na=False)
]
table_y = table_y[table_y["label"] > 0].drop_duplicates("grid_code")


table = None
table = (
        table_h.merge(table_y[["grid_code", "label"]], on="grid_code", how="inner")
        .sort_values(["lat", "lon"])
        .reset_index(drop=True)
    )

counts_per_state = (
    table
    .groupby("ADM1_NAME")
    .size()
    .reset_index(name="n_datapoints")
)

state_order = counts_per_state.sort_values(
    "n_datapoints", ascending=False
)["ADM1_NAME"]

import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(
    2, 1,
    figsize=(12, 10),
    sharex=True,
    gridspec_kw={"height_ratios": [1, 3]}
)

# --- Top: counts per state ---
sns.barplot(
    data=counts_per_state,
    x="ADM1_NAME",
    y="n_datapoints",
    order=state_order,
    ax=axes[0]
)

axes[0].set_ylabel("Number of datapoints")
axes[0].set_title("Datapoints per state")

# --- Bottom: box + whisker ---
sns.boxplot(
    data=table,
    x="ADM1_NAME",
    y=value_name,
    order=state_order,
    ax=axes[1],
    showfliers=False  # cleaner; remove if you want outliers
)

axes[1].set_ylabel(value_name)
axes[1].set_xlabel("State")
axes[1].set_title(f"Distribution of {value_name} by state")

# Rotate labels
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %%
# For sample logic: I.e., filter by harvest ared of greated than 2.5 km
csv_path  = H_CSV
value_name="maize_area_ha"
usecols = ["grid_code", "x", "y", "FIPS0", "ADM1_NAME", "year_data", SPAM_CROP_COL]
table = pd.read_csv(csv_path, usecols=usecols, encoding="utf-8-sig")
table = table.rename(columns={"x": "lon", "y": "lat", SPAM_CROP_COL: value_name})

table["grid_code"] = table["grid_code"].astype(str)
table["FIPS0"] = table["FIPS0"].astype(str).str.upper()
table["ADM1_NAME"] = table["ADM1_NAME"].astype(str)
table["year_data"] = table["year_data"].astype(str)
table[value_name] = pd.to_numeric(table[value_name], errors="coerce")

table_h = table[
    table["FIPS0"].eq(COUNTRY_CODE)
    # & table["year_data"].str.contains(str(LABEL_YEAR), na=False)
]
table_h = table_h[table_h["maize_area_ha"] >= MIN_AREA_HA].drop_duplicates("grid_code")


csv_path  = Y_CSV
value_name="label"
usecols = ["grid_code", "x", "y", "FIPS0", "ADM1_NAME", "year_data", SPAM_CROP_COL]
table = pd.read_csv(csv_path, usecols=usecols, encoding="utf-8-sig")
table = table.rename(columns={"x": "lon", "y": "lat", SPAM_CROP_COL: value_name})

table["grid_code"] = table["grid_code"].astype(str)
table["FIPS0"] = table["FIPS0"].astype(str).str.upper()
table["ADM1_NAME"] = table["ADM1_NAME"].astype(str)
table["year_data"] = table["year_data"].astype(str)
table[value_name] = pd.to_numeric(table[value_name], errors="coerce")

table_y = table[
    table["FIPS0"].eq(COUNTRY_CODE)
    # & table["year_data"].str.contains(str(LABEL_YEAR), na=False)
]
table_y = table_y[table_y["label"] > 0].drop_duplicates("grid_code")


table = None
table = (
        table_h.merge(table_y[["grid_code", "label"]], on="grid_code", how="inner")
        .sort_values(["lat", "lon"])
        .reset_index(drop=True)
    )

counts_per_state = (
    table
    .groupby("ADM1_NAME")
    .size()
    .reset_index(name="n_datapoints")
)

state_order = counts_per_state.sort_values(
    "n_datapoints", ascending=False
)["ADM1_NAME"]

import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(
    2, 1,
    figsize=(12, 10),
    sharex=True,
    gridspec_kw={"height_ratios": [1, 3]}
)

# --- Top: counts per state ---
sns.barplot(
    data=counts_per_state,
    x="ADM1_NAME",
    y="n_datapoints",
    order=state_order,
    ax=axes[0]
)

axes[0].set_ylabel("Number of datapoints")
axes[0].set_title("Datapoints per state")

# --- Bottom: box + whisker ---
sns.boxplot(
    data=table,
    x="ADM1_NAME",
    y=value_name,
    order=state_order,
    ax=axes[1],
    showfliers=False  # cleaner; remove if you want outliers
)

axes[1].set_ylabel(value_name)
axes[1].set_xlabel("State")
axes[1].set_title(f"Distribution of {value_name} by state")

# Rotate labels
plt.xticks(rotation=45, ha="right")

plt.tight_layout()
plt.show()

# %%
bins = np.arange(0, 20 + 2.5, 2.5)
labels = [f"{bins[i]}–{bins[i+1]}" for i in range(len(bins) - 1)]

df["label_bin"] = pd.cut(df["label"], bins=bins, labels=labels, include_lowest=True)

plt.figure(figsize=(10, 6))

sns.countplot(
    data=df,
    x="label_bin",
    hue="state",
)

plt.xlabel("Label bins")
plt.ylabel("Count")
plt.title("Label Distribution by State")
plt.legend(title="State")
plt.tight_layout()
plt.show()

g = sns.FacetGrid(df, col="state", col_wrap=3, height=3)
g.map_dataframe(sns.countplot, x="label_bin")

g.set_axis_labels("Label bins", "Count")
g.set_titles("{col_name}")

for ax in g.axes.flat:
    ax.tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h1>Get States Data from SPAM</h1>

# %%
# ring_dict = {}
# cent_coord_dict={}
all_state_dfs = []
state_spatials = {}
state_point_names  = {}

for STATE in STATES[:]:
    print(STATE)

    # rings, lon, lat, _ = get_state_ring(STATE)
    # ring_dict[STATE] = rings
    # cent_coord_dict[STATE] = (lon, lat)
    
    # plot_state(ring_dict, cent_coord_dict, STATE)

    area_df = load_spam_value(H_CSV, "maize_area_ha", STATE_NAME=STATE)
    area_df = area_df[area_df["maize_area_ha"] >= MIN_AREA_HA].drop_duplicates("grid_code")
    
    yield_df = load_spam_value(Y_CSV, "label", STATE_NAME=STATE)
    yield_df = yield_df[yield_df["label"] > 0].drop_duplicates("grid_code")
    
    df = (
        area_df.merge(yield_df[["grid_code", "label"]], on="grid_code", how="inner")
        .sort_values(["lat", "lon"])
        .reset_index(drop=True)
    )
    
    if df.empty:
        raise RuntimeError("No Illinois points found after filtering.")

    df["state"] = STATE
    all_state_dfs.append(df)
    
    spatials = [
        PointBuffer(lon=float(row.lon), lat=float(row.lat), buffer_m=BUFFER_M)
        for row in df.itertuples(index=False)
    ]
    state_spatials[STATE] = spatials
    state_point_names[STATE] = [f"p{i:05d}" for i in range(len(spatials))]
    
    print(f"points={len(df)}")
    print(df[["maize_area_ha", "label"]].describe().T)

df = (
    pd.concat(all_state_dfs, ignore_index=True)
    if all_state_dfs
    else pd.DataFrame()
)

print(f"Total points across states: {len(df)}")
df.head()
# Out:
# Minnesota
# points=485
#                count         mean         std     min     25%     50%     75%  \
# maize_area_ha  485.0  3314.720206  412.817263  2502.5  3023.3  3332.0  3579.9
# label          485.0    16.050309    1.148726    11.3    15.4    16.3    17.0
#
#                   max
# maize_area_ha  4845.1
# label            17.3
# South Dakota
# points=41
#                count         mean         std     min     25%     50%     75%  \
# maize_area_ha   41.0  3181.456098  537.236735  2507.0  2716.8  3140.6  3530.1
# label           41.0     6.739024    4.197135     0.1     2.3     9.3     9.3
#
#                   max
# maize_area_ha  4601.4
# label            17.0
# Kansas
# points=63
#                count         mean         std     min     25%     50%  \
# maize_area_ha   63.0  3098.025397  516.590658  2504.2  2728.0  2940.7
# label           63.0     7.936508    3.507747     3.1     4.3    10.4
#
#                    75%     max
# maize_area_ha  3360.85  5000.5
# ...

# %%
df
# Out:
#      grid_code      lon      lat  maize_area_ha  label      state
# 0      2407243 -96.3750  43.5417         3076.7   15.0  Minnesota
# 1      2407244 -96.2917  43.5417         3173.0   15.2  Minnesota
# 2      2407245 -96.2083  43.5417         3064.3   15.3  Minnesota
# 3      2407246 -96.1250  43.5417         2985.4   15.4  Minnesota
# 4      2407247 -96.0417  43.5417         3662.1   15.5  Minnesota
# ...        ...      ...      ...            ...    ...        ...
# 2544   2709746 -87.7917  37.7083         3335.5   14.0   Kentucky
# 2545   2709747 -87.7083  37.7083         3105.4   14.0   Kentucky
# 2546   2709748 -87.6250  37.7083         2987.3   13.9   Kentucky
# 2547   2705425 -87.8750  37.7917         2599.1   13.5   Kentucky
# 2548   2705427 -87.7083  37.7917         2905.6   14.1   Kentucky
#
# [2549 rows x 6 columns]

# %% [markdown]
# <h1>Export Embeddings Per State</h1>

# %%
EXPORT_ROOT.mkdir(parents=True, exist_ok=True)

for STATE in STATES:
    state_dir = EXPORT_ROOT / STATE
    state_dir.mkdir(parents=True, exist_ok=True)

has_export = any(EXPORT_ROOT.glob("p*.npz")) or (EXPORT_ROOT / "_all_points_manifest.json").exists()

# %%
str(EXPORT_ROOT / STATE)
# Out:
# 'exports_tile/Kentucky'

# %%
df[df['state']=='Ohio']
# Out:
#      grid_code     lon      lat  maize_area_ha  label state
# 2275   2601796 -83.625  39.7917         2571.1   12.7  Ohio

# %%
STATES[4:]
# Out:
# ['Illinois', 'Ohio', 'Indiana', 'Missouri', 'Wisconsin', 'Kentucky']

# %%
from rs_embed import ExportConfig, ExportTarget
for STATE in STATES[2:]:

    manifests = export_batch(
        spatials=state_spatials[STATE],
        temporal=TEMPORAL,
        models=MODEL_LIST,
        target=ExportTarget.per_item(str(EXPORT_ROOT / STATE), names=state_point_names[STATE]),
        output=OutputSpec.grid(),
        backend="gee",
        device="auto",
        config=ExportConfig(
            save_inputs=SAVE_INPUTS,
            save_embeddings=True,
            save_manifest=True,
            chunk_size=8,
            num_workers=4,
            resume=True,
            continue_on_error=True,
            show_progress=True,
            input_prep=InputPrepSpec('tile', max_tiles=100)# you can chage it to 'tile' if you want to keep original resolution
        ),
    )
    print(f"exported_manifests={len(manifests)}")
# Out:
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# /data/keeling/a/jdnied2/c/598/rs-embed/src/rs_embed/tools/runtime.py:250: UserWarning: AgriFM received CHW input and is repeating it to T=8. This changes temporal semantics; prefer real TCHW input when available.
#   out = embedder.get_embedding(**kwargs)
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# exported_manifests=63
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
# ...
# ...
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
! scancel 518810

# %% [markdown]
# <h1>Ingest Embeddings</h1>

# %%
# temp = np.load("./exports/Illinois/p00476.npz", allow_pickle=False)
# for key in temp.files:
#     arr = temp[key]
#     print(key, arr.shape)

# %%
STATES
# Out:
# ['Minnesota',
#  'South Dakota',
#  'Kansas',
#  'Iowa',
#  'Illinois',
#  'Ohio',
#  'Indiana',
#  'Missouri',
#  'Wisconsin',
#  'Kentucky']

# %%
X_by_state_by_model = {} 

for STATE in STATES[:]:
    print(STATE)

    df_state = df[df["state"].str.strip() == STATE]
    
    point_to_row = {point_key(row.lon, row.lat): i for i, row in enumerate(df_state.itertuples(index=False))}
    vectors_by_model = {}
    
    for pm, npz_path, _ in iter_export_points(EXPORT_ROOT / STATE):
        row_index = point_row_index(pm, point_to_row)
        if row_index is None or not npz_path.exists():
            continue
    
        with np.load(npz_path, allow_pickle=False) as bundle:
            for model, vec in iter_model_vectors(bundle, pm):
                vectors_by_model.setdefault(model, {})[int(row_index)] = vec
    
    X_by_model = {}
    summary_rows = []
    
    for model, row_map in sorted(vectors_by_model.items()):
        dims = {int(vec.shape[0]) for vec in row_map.values()}
        if len(dims) != 1:
            print(f"skip {model}: inconsistent dims {sorted(dims)}")
            continue
    
        dim = dims.pop()
        X = np.full((len(df_state), dim), np.nan, dtype=np.float32)
        for row_index, vec in row_map.items():
            X[row_index] = vec
    
        valid_rows = int(np.isfinite(X).all(axis=1).sum())
        X_by_model[model] = X
        summary_rows.append(
            {
                "model": model,
                "dim": dim,
                "valid_rows": valid_rows,
                "coverage": valid_rows / len(df_state),
            }
        )
    
    X_by_state_by_model[STATE] = X_by_model
    
    embed_df = (
        pd.DataFrame(summary_rows).sort_values("coverage", ascending=False).reset_index(drop=True)
    )
    if embed_df.empty:
        raise RuntimeError(f"No usable embeddings found in {EXPORT_ROOT}.")
    
    print(embed_df)
# Out:
# Minnesota
#        model   dim  valid_rows  coverage
# 0     agrifm  1024         485       1.0
# 1     satmae  1024         485       1.0
# 2  satvision  4096         485       1.0
# 3    terrafm   768         485       1.0
# South Dakota
#        model   dim  valid_rows  coverage
# 0     agrifm  1024          41       1.0
# 1     satmae  1024          41       1.0
# 2  satvision  4096          41       1.0
# 3    terrafm   768          41       1.0
# Kansas
#        model   dim  valid_rows  coverage
# 0     agrifm  1024          63       1.0
# 1     satmae  1024          63       1.0
# 2  satvision  4096          63       1.0
# 3    terrafm   768          63       1.0
# Iowa
#        model   dim  valid_rows  coverage
# 0     agrifm  1024         695       1.0
# 1     satmae  1024         695       1.0
# 2  satvision  4096         695       1.0
# 3    terrafm   768         695       1.0
# Illinois
#        model   dim  valid_rows  coverage
# 0     agrifm  1024         991       1.0
# ...

# %%
OutputSpec.grid()
# Out:
# OutputSpec(mode='grid', pooling='mean', grid_orientation='north_up')

# %% [markdown]
# <h1>Train/Test Models on States with RF linear probing</h1>

# %%
STATES
# Out:
# ['Minnesota',
#  'South Dakota',
#  'Kansas',
#  'Iowa',
#  'Illinois',
#  'Indiana',
#  'Missouri',
#  'Wisconsin',
#  'Kentucky']

# %%
def rmse(y_true, y_pred):
    return float(np.sqrt(mean_squared_error(y_true, y_pred)))

def make_df(results):

    rows = []
    for state, models in results.items():
        for model, metrics in models.items():
            row = {"state": state, "model": model, **metrics}
            rows.append(row)

    return pd.DataFrame(rows)

# %% [markdown]
# <h2>Train/Test per State</h2>

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import TransformedTargetRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error
import numpy as np

results_by_state = {}

TEST_SIZE = 0.2
SEED = 42

for S, STATE in enumerate(STATES):
    state_mask = df["state"].str.strip() == STATE
    y_state = df.loc[state_mask, "label"].to_numpy(dtype=np.float32)

    print(f"{S}: {STATE}\ttotal: {y_state.shape}")

    results_by_state[STATE] = {}

    for model in MODEL_LIST:
        X_state = X_by_state_by_model[STATE][model]

        X_train, X_test, y_train, y_test = train_test_split(
            X_state,
            y_state,
            test_size=TEST_SIZE,
            random_state=SEED,
            shuffle=True,
        )

        print(f"  {model}\ttrain: {y_train.shape}, test: {y_test.shape}")

        rf = RandomForestRegressor(
            n_estimators=200,          # can tune
            random_state=SEED,
            n_jobs=-1,
            min_samples_leaf=3,        # can tune
        )

        # Log-transform target: z = log1p(y), inverse: y = expm1(z)
        eps = 1e-3  # small positive offset so log10 is defined
        reg = TransformedTargetRegressor(
            regressor=rf,
            func=lambda y: np.log10(y + eps),
            inverse_func=lambda z: (10 ** z) - eps,
            check_inverse=False,  # lambdas sometimes trigger inverse check issues
        )

        reg.fit(X_train, y_train)
        pred = reg.predict(X_test).astype(np.float32)

        out = {
            "r2": r2_score(y_test, pred),
            "rmse": rmse(y_test, pred),
            "mae": mean_absolute_error(y_test, pred),
            "n_train": int(len(y_train)),
            "n_test": int(len(y_test)),
            "note": "state_train_test_split",
        }

        results_by_state[STATE][model] = out

print(results_by_state)
# Out:
# 0: Minnesota	total: (485,)
#   terrafm	train: (388,), test: (97,)
#   satvision	train: (388,), test: (97,)
#   agrifm	train: (388,), test: (97,)
#   satmae	train: (388,), test: (97,)
# 1: South Dakota	total: (41,)
#   terrafm	train: (32,), test: (9,)
#   satvision	train: (32,), test: (9,)
#   agrifm	train: (32,), test: (9,)
#   satmae	train: (32,), test: (9,)
# 2: Kansas	total: (63,)
#   terrafm	train: (50,), test: (13,)
#   satvision	train: (50,), test: (13,)
#   agrifm	train: (50,), test: (13,)
#   satmae	train: (50,), test: (13,)
# 3: Iowa	total: (695,)
#   terrafm	train: (556,), test: (139,)
#   satvision	train: (556,), test: (139,)
#   agrifm	train: (556,), test: (139,)
#   satmae	train: (556,), test: (139,)
# 4: Illinois	total: (991,)
#   terrafm	train: (792,), test: (199,)
#   satvision	train: (792,), test: (199,)
#   agrifm	train: (792,), test: (199,)
#   satmae	train: (792,), test: (199,)
# 5: Indiana	total: (93,)
#   terrafm	train: (74,), test: (19,)
# ...

# %%
results_by_state = make_df(results_by_state)
results_by_state
# Out:
#            state      model        r2      rmse       mae  n_train  n_test  \
# 0      Minnesota    terrafm  0.601551  0.794943  0.537588      388      97
# 1      Minnesota  satvision  0.579947  0.816210  0.568276      388      97
# 2      Minnesota     agrifm  0.545148  0.849346  0.616163      388      97
# 3      Minnesota     satmae  0.433465  0.947901  0.675739      388      97
# 4   South Dakota    terrafm  0.634891  1.993898  1.652709       32       9
# 5   South Dakota  satvision  0.918334  0.943001  0.587292       32       9
# 6   South Dakota     agrifm  0.833055  1.348276  0.961980       32       9
# 7   South Dakota     satmae  0.801812  1.469031  1.290600       32       9
# 8         Kansas    terrafm  0.342453  2.855420  2.289062       50      13
# 9         Kansas  satvision  0.298366  2.949593  2.790229       50      13
# 10        Kansas     agrifm  0.461137  2.584912  2.286837       50      13
# ...

# %%
print(results_by_state.groupby("model")[["r2", "rmse", "mae"]].mean())
print()
print(results_by_state.groupby("model")[["r2", "rmse", "mae"]].std())
# Out:
#                  r2      rmse       mae
# model
# agrifm     0.183584  0.928780  0.694463
# satmae     0.064280  1.004160  0.730275
# satvision  0.574428  0.759535  0.583893
# terrafm    0.336644  0.933183  0.688438
#
#                  r2      rmse       mae
# model
# agrifm     0.516769  0.721763  0.654738
# satmae     0.505398  0.712055  0.559791
# satvision  0.215847  0.873019  0.810479
# terrafm    0.421962  0.851481  0.704111

# %%
print(results_by_state.groupby("model")[["r2", "rmse", "mae"]].mean())
print()
print(results_by_state.groupby("model")[["r2", "rmse", "mae"]].std()) #log10
# Out:
#                  r2      rmse       mae
# model
# agrifm     0.211451  0.911263  0.671534
# satmae     0.087185  0.999380  0.780212
# satvision  0.557602  0.823268  0.633446
# terrafm    0.312148  0.953480  0.714941
#
#                  r2      rmse       mae
# model
# agrifm     0.494081  0.733690  0.655911
# satmae     0.467364  0.750854  0.666705
# satvision  0.215192  0.852471  0.829727
# terrafm    0.437521  0.889415  0.741594

# %%
print(results_by_state.groupby("model")[["r2", "rmse", "mae"]].mean())
print()
print(results_by_state.groupby("model")[["r2", "rmse", "mae"]].std())
# Out:
#                  r2      rmse       mae
# model
# agrifm     0.214355  0.903729  0.682196
# satmae     0.088841  1.000481  0.778774
# satvision  0.561467  0.802447  0.615668
# terrafm    0.322389  0.931887  0.704668
#
#                  r2      rmse       mae
# model
# agrifm     0.495769  0.720825  0.664881
# satmae     0.465526  0.746185  0.663507
# satvision  0.219945  0.847712  0.826799
# terrafm    0.443183  0.859411  0.729079

# %% [markdown]
# <h2>Train/test on all states</h2>

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# results_all_data = {}
# preds_all_data = []

# TEST_SIZE = 0.2
# SEED = 42

# y_all = df["label"].to_numpy(dtype=np.float32)

# for model in MODEL_LIST:
#     X_all = np.concatenate(
#         [X_by_state_by_model[state][model] for state in STATES],
#         axis=0,
#     )

#     X_train, X_test, y_train, y_test = train_test_split(
#         X_all,
#         y_all,
#         test_size=TEST_SIZE,
#         random_state=SEED,
#         shuffle=True,
#     )

#     print(f"{model}\ttrain: {y_train.shape}, test: {y_test.shape}")

#     reg = RandomForestRegressor(
#         n_estimators=200,
#         random_state=SEED,
#         n_jobs=-1,
#     )

#     reg.fit(X_train, y_train)
#     pred = reg.predict(X_test).astype(np.float32)

#     results_all_data[model] = {
#         "r2": r2_score(y_test, pred),
#         "rmse": rmse(y_test, pred),
#         "mae": mean_absolute_error(y_test, pred),
#         "n_train": int(len(y_train)),
#         "n_test": int(len(y_test)),
#         "note": "all_data_train_test_split",
#     }

#     preds_all_data.append(
#         pd.DataFrame({
#             "model": model,
#             "y_true": y_test,
#             "y_pred": pred,
#         })
#     )

# results_all_data = (
#     pd.DataFrame.from_dict(results_all_data, orient="index")
#     .reset_index()
#     .rename(columns={"index": "model"})
# )

# preds_all_data = pd.concat(preds_all_data, ignore_index=True)

# # Plot predictions vs truth
# plt.figure(figsize=(8, 8))

# sns.scatterplot(
#     data=preds_all_data,
#     x="y_true",
#     y="y_pred",
#     hue="model",
#     alpha=0.7,
# )

# lims = [
#     min(preds_all_data["y_true"].min(), preds_all_data["y_pred"].min()),
#     max(preds_all_data["y_true"].max(), preds_all_data["y_pred"].max()),
# ]

# plt.plot(lims, lims, "r--", label="x = y")

# plt.xlabel("True label")
# plt.ylabel("Predicted label")
# plt.title("Random Forest Predictions vs Truth by Embedding Model")
# plt.xlim(lims)
# plt.ylim(lims)
# plt.legend()
# plt.tight_layout()
# plt.show()

# results_all_data

# %%
print(results_all_data.groupby("model")[["r2", "rmse", "mae"]].mean())
print()
print(results_all_data.groupby("model")[["r2", "rmse", "mae"]].std()) #log10
# Out:
#                  r2      rmse       mae
# model
# agrifm     0.689767  1.599725  1.071325
# satmae     0.294631  2.412180  1.905922
# satvision  0.712646  1.539607  1.027739
# terrafm    0.620788  1.768652  1.334673
#
#            r2  rmse  mae
# model
# agrifm    NaN   NaN  NaN
# satmae    NaN   NaN  NaN
# satvision NaN   NaN  NaN
# terrafm   NaN   NaN  NaN

# %% [markdown]
# <h2>State cross validation</h2>

# %%
results = {}
# model = "satmae"
for S, STATE in enumerate(STATES):
    y_test = df[df["state"].str.strip() == STATE]["label"].to_numpy(dtype=np.float32)
    y_train = df[df["state"].str.strip() != STATE]["label"].to_numpy(dtype=np.float32)

    print(f"{S}: {STATE}\ttrain: {y_train.shape}, test: {y_test.shape}")
    
    for model in MODEL_LIST:
    
        X_test = X_by_state_by_model[STATE][model]
        X_train = np.concatenate([X_by_state_by_model[s][model] for s in STATES if s != STATE])
    
    
        reg = RandomForestRegressor(n_estimators=200, random_state=42, n_jobs=-1)
        reg.fit(X_train, y_train)
        pred = reg.predict(X_test).astype(np.float32)
    
        out = {
                "r2": r2_score(y_test, pred),
                "rmse": rmse(y_test, pred),
                "mae": mean_absolute_error(y_test, pred),
                "n_train": int(len(y_train)),
                "n_test": int(len(y_test)),
                "note": "ok",
            }
    
        if STATE not in results:
            results[STATE] = dict()
    
        results[STATE][model] = out
        
print(results)
# Out:
# Minnesota	train: (2065,), test: (485,)
# South Dakota	train: (2509,), test: (41,)
# Kansas	train: (2487,), test: (63,)
# Iowa	train: (1855,), test: (695,)
# Illinois	train: (1559,), test: (991,)
# Ohio	train: (2549,), test: (1,)
# /data/keeling/a/jdnied2/f/anaconda3/envs/rsembed/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1288: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /data/keeling/a/jdnied2/f/anaconda3/envs/rsembed/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1288: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# /data/keeling/a/jdnied2/f/anaconda3/envs/rsembed/lib/python3.12/site-packages/sklearn/metrics/_regression.py:1288: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# ...

# %%
import pandas as pd

rows = []
for state, models in results.items():
    for model, metrics in models.items():
        row = {"state": state, "model": model, **metrics}
        rows.append(row)

df_results = pd.DataFrame(rows)

# %%
df_results.groupby("model")[["r2", "rmse", "mae"]].mean()
df_results.groupby("model")[["r2", "rmse", "mae"]].std()
# Out:
#                    r2      rmse       mae
# model
# agrifm     -62.210551  3.417295  3.176257
# satmae     -72.975747  3.273354  2.919110
# satvision -132.307625  3.525648  3.110117
# terrafm    -60.541829  3.220377  2.893940

# %%
df_results.groupby("model")[["r2", "rmse", "mae"]].std()
# Out:
#                    r2      rmse       mae
# model
# agrifm     116.777719  1.070137  0.892999
# satmae     170.357802  1.427075  1.345266
# satvision  322.454289  0.837507  0.790556
# terrafm    126.755312  1.819690  1.643171

# %%
import numpy as np

def weighted_avg(group, metric):
    return np.average(group[metric], weights=group["n_test"])

df_results.groupby("model").apply(lambda g: weighted_avg(g, "r2"))
# Out:
# model
# agrifm      NaN
# satmae      NaN
# satvision   NaN
# terrafm     NaN
# dtype: float64

# %%
df.groupby("state")["label"].describe()
# Out:
#               count       mean       std   min   25%   50%    75%   max
# state
# Illinois      991.0   9.551261  0.559524   7.1   9.5   9.7   9.80  11.8
# Indiana        93.0  12.490323  0.918182  11.1  11.9  12.1  12.90  15.3
# Iowa          695.0  12.464892  1.311303   8.7  12.3  12.4  12.70  15.6
# Kansas         63.0   7.936508  3.507747   3.1   4.3  10.4  10.50  13.5
# Kentucky       15.0  13.686667  0.285023  13.2  13.5  13.6  13.95  14.1
# Minnesota     485.0  16.050309  1.148726  11.3  15.4  16.3  17.00  17.3
# Missouri       35.0   7.940000  0.135473   7.7   7.8   8.0   8.00   8.1
# Ohio            1.0  12.700000       NaN  12.7  12.7  12.7  12.70  12.7
# South Dakota   41.0   6.739024  4.197135   0.1   2.3   9.3   9.30  17.0
# Wisconsin     131.0  11.871756  0.807777   8.9  11.8  12.0  12.40  12.6

# %% [markdown]
# <h1>Loop on model space</h1>

# %% [markdown]
# <h2>Definitions for models</h2>

# %%
# !pip install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.7/131.7 MB 157.0 MB/s  0:00:000:00:0100:01
# ...

# %%
import numpy as np
import pandas as pd
import warnings

from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.compose import TransformedTargetRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from xgboost import XGBRegressor
SEED = 42

# %%
model_zoo = {
    "rf": RandomForestRegressor(
        n_estimators=500,
        random_state=SEED,
        n_jobs=-1,
        min_samples_leaf=3,
        max_features="sqrt"
    ),

    # small MLP
    "mlp_small": Pipeline([
        ("scaler", StandardScaler()),
        ("mlp", MLPRegressor(
            hidden_layer_sizes=(128,),
            activation="relu",
            solver="adam",
            alpha=1e-4,
            learning_rate_init=1e-3,
            max_iter=400,
            early_stopping=True,
            validation_fraction=0.15,
            n_iter_no_change=20,
            random_state=SEED
        ))
    ]),
    # deeper / larger DNN-style MLP
    "dnn_large": Pipeline([
        ("scaler", StandardScaler()),
        ("mlp", MLPRegressor(
            hidden_layer_sizes=(512, 256, 128),
            activation="relu",
            solver="adam",
            alpha=1e-4,
            learning_rate_init=5e-4,
            max_iter=600,
            early_stopping=True,
            validation_fraction=0.15,
            n_iter_no_change=25,
            random_state=SEED
        ))
    ]),
    "xgb" : XGBRegressor(
        n_estimators=1200,
        max_depth=6,
        learning_rate=0.03,
        subsample=0.8,
        colsample_bytree=0.8,
        reg_alpha=0.0,
        reg_lambda=1.0,
        objective="reg:squarederror",
        random_state=SEED,
        n_jobs=-1
    )
}

# %% [markdown]
# <h2>Train/Test split per state</h2>

# %%
from sklearn.model_selection import train_test_split
from sklearn.compose import TransformedTargetRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error
import numpy as np

TEST_SIZE = 0.2
SEED = 42

rows= []
for S, STATE in enumerate(STATES):
    state_mask = df["state"].str.strip() == STATE
    y_state = df.loc[state_mask, "label"].to_numpy(dtype=np.float32)

    print(f"{S}: {STATE}\ttotal: {y_state.shape}")

    results_by_state[STATE] = {}

    for model in MODEL_LIST:
        X_state = X_by_state_by_model[STATE][model]

        X_train, X_test, y_train, y_test = train_test_split(
            X_state,
            y_state,
            test_size=TEST_SIZE,
            random_state=SEED,
            shuffle=True,
        )

        for arch_name, base_reg in model_zoo.items():
            # consistent target transform for all regressors
            reg = base_reg

            reg.fit(X_train, y_train)
            pred = reg.predict(X_test).astype(np.float32)
            pred = np.clip(pred, 0.0, None)


            rows.append({
                    "state" : STATE,
                    "embedding_model": model,
                    "arch": arch_name,
                    "r2": r2_score(y_test, pred),
                    "rmse": rmse(y_test, pred),
                    "mae": mean_absolute_error(y_test, pred),
                    # "rmsle": rmsle(y_test, pred),
                    "n_train": int(len(y_train)),
                    "n_test": int(len(y_test)),
                })
            
df_cmp = pd.DataFrame(rows)
# Out:
# 0: Minnesota	total: (485,)
# 1: South Dakota	total: (41,)
# 2: Kansas	total: (63,)
# 3: Iowa	total: (695,)
# 4: Illinois	total: (991,)
# 5: Indiana	total: (93,)
# /data/keeling/a/jdnied2/f/anaconda3/envs/rsembed/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:785: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (400) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 6: Missouri	total: (35,)
# 7: Wisconsin	total: (131,)
# 8: Kentucky	total: (15,)

# %%
macro = (
    df_cmp.groupby(["embedding_model", "arch"])[["r2", "rmse", "mae"]]
    .mean()
    .sort_values(["r2", "rmse"], ascending=[False, True])
)
macro
# Out:
#                                    r2      rmse       mae
# embedding_model arch
# satvision       xgb          0.623133  0.775766  0.566702
#                 rf           0.513538  0.804849  0.626098
# terrafm         rf           0.297802  1.000764  0.778011
#                 xgb          0.291529  1.025346  0.770837
# agrifm          xgb          0.224590  0.910199  0.632974
# satmae          rf           0.098308  1.039451  0.750141
#                 xgb          0.078292  0.998413  0.700451
# agrifm          rf           0.075637  1.095952  0.819735
# satvision       dnn_large  -12.068378  1.474967  1.108441
#                 mlp_small  -20.401807  1.374649  1.078205
# agrifm          mlp_small -149.861704  3.304968  2.782577
# satmae          dnn_large -162.909004  3.173269  2.493166
# terrafm         dnn_large -164.017979  2.566914  2.063846
# agrifm          dnn_large -176.459484  2.994246  2.439195
# satmae          mlp_small -272.001790  4.232806  3.318468
# ...

# %%
# weight by size of state test date
def wavg(g, col):
    return np.average(g[col], weights=g["n_test"])

weighted_rows = []
for (emb, arch), g in df_cmp.groupby(["embedding_model", "arch"]):
    weighted_rows.append({
        "embedding_model": emb,
        "arch": arch,
        "r2_weighted": wavg(g, "r2"),
        "rmse_weighted": wavg(g, "rmse"),
        "mae_weighted": wavg(g, "mae"),
    })
weighted = pd.DataFrame(weighted_rows).sort_values(["r2_weighted", "rmse_weighted"], ascending=[False, True])
macro_weighted = (
    weighted.groupby(["embedding_model", "arch"])[["r2_weighted", "rmse_weighted"]]
    .mean()
    .sort_values(["r2_weighted", "rmse_weighted"], ascending=[False, True])
)
macro_weighted
# Out:
#                            r2_weighted  rmse_weighted
# embedding_model arch
# satvision       xgb           0.557284       0.639747
# terrafm         xgb           0.510058       0.666231
# satvision       rf            0.483133       0.678847
# terrafm         rf            0.435911       0.703084
# agrifm          xgb           0.397356       0.726823
#                 rf            0.253491       0.821139
# satmae          rf            0.170434       0.845060
#                 xgb           0.162549       0.837824
# satvision       dnn_large    -1.064786       0.942236
#                 mlp_small    -1.827292       0.894791
# agrifm          mlp_small   -15.791463       2.014221
# terrafm         dnn_large   -17.795941       1.573223
# agrifm          dnn_large   -19.012662       1.827494
# satmae          dnn_large   -23.439380       2.374049
#                 mlp_small   -35.763758       2.941843
# terrafm         mlp_small   -47.847510       2.509167

# %% [markdown]
# <h2>All states</h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

results_all_data = {}
preds_all_data = []

TEST_SIZE = 0.2
SEED = 42

y_all = df["label"].to_numpy(dtype=np.float32)

rows= []
preds_all_data = [] 

for model in MODEL_LIST:
    X_all = np.concatenate(
        [X_by_state_by_model[state][model] for state in STATES],
        axis=0,
    )

    X_train, X_test, y_train, y_test = train_test_split(
        X_all,
        y_all,
        test_size=TEST_SIZE,
        random_state=SEED,
        shuffle=True,
    )

    print(f"{model}\ttrain: {y_train.shape}, test: {y_test.shape}")

    for arch_name, base_reg in model_zoo.items():
        # consistent target transform for all regressors
        reg = base_reg
        
        reg.fit(X_train, y_train)
        pred = reg.predict(X_test).astype(np.float32)
        pred = np.clip(pred, 0.0, None)
        
        
        rows.append({
                        "embedding_model": model,
                        "arch": arch_name,
                        "r2": r2_score(y_test, pred),
                        "rmse": rmse(y_test, pred),
                        "mae": mean_absolute_error(y_test, pred),
                        # "rmsle": rmsle(y_test, pred),
                        "n_train": int(len(y_train)),
                        "n_test": int(len(y_test)),
                    })
        
        preds_all_data.append(
            pd.DataFrame({
                "embedding_model": model,
                "arch": arch_name,
                "y_true": y_test,
                "y_pred": pred,
            })
            )

df_arch_states = pd.DataFrame(rows)

df_arch_states
# Out:
# terrafm	train: (2039,), test: (510,)
# satvision	train: (2039,), test: (510,)
# agrifm	train: (2039,), test: (510,)
# satmae	train: (2039,), test: (510,)
#    embedding_model       arch        r2      rmse       mae  n_train  n_test
# 0          terrafm         rf  0.562692  1.899308  1.464276     2039     510
# 1          terrafm  mlp_small  0.483511  2.064107  1.619005     2039     510
# 2          terrafm  dnn_large  0.649705  1.699880  1.317768     2039     510
# 3          terrafm        xgb  0.686053  1.609274  1.202460     2039     510
# 4        satvision         rf  0.693391  1.590354  1.073341     2039     510
# 5        satvision  mlp_small  0.637290  1.729742  1.275495     2039     510
# 6        satvision  dnn_large  0.710485  1.545387  1.108114     2039     510
# 7        satvision        xgb  0.738040  1.470006  0.969284     2039     510
# 8           agrifm         rf  0.679955  1.624826  1.106518     2039     510
# ...

# %%
macro_all = (
    df_arch_states.groupby(["embedding_model", "arch"])[["r2", "rmse", "mae"]]
    .mean()
    .sort_values(["r2", "rmse"], ascending=[False, True])
)
macro_all
# Out:
#                                  r2      rmse       mae
# embedding_model arch
# satvision       xgb        0.738040  1.470006  0.969284
#                 dnn_large  0.710485  1.545387  1.108114
# agrifm          dnn_large  0.701102  1.570230  1.115095
#                 xgb        0.699077  1.575540  1.045524
# satvision       rf         0.693391  1.590354  1.073341
# terrafm         xgb        0.686053  1.609274  1.202460
# agrifm          rf         0.679955  1.624826  1.106518
# terrafm         dnn_large  0.649705  1.699880  1.317768
# agrifm          mlp_small  0.641714  1.719161  1.240097
# satvision       mlp_small  0.637290  1.729742  1.275495
# terrafm         rf         0.562692  1.899308  1.464276
#                 mlp_small  0.483511  2.064107  1.619005
# satmae          xgb        0.327705  2.354949  1.866801
#                 rf         0.278621  2.439401  1.954355
#                 dnn_large  0.201664  2.566223  2.005499
# ...

# %%
plt.figure()
# Out:
#      grid_code      lon      lat  maize_area_ha  label      state
# 0      2407243 -96.3750  43.5417         3076.7   15.0  Minnesota
# 1      2407244 -96.2917  43.5417         3173.0   15.2  Minnesota
# 2      2407245 -96.2083  43.5417         3064.3   15.3  Minnesota
# 3      2407246 -96.1250  43.5417         2985.4   15.4  Minnesota
# 4      2407247 -96.0417  43.5417         3662.1   15.5  Minnesota
# ...        ...      ...      ...            ...    ...        ...
# 2544   2709746 -87.7917  37.7083         3335.5   14.0   Kentucky
# 2545   2709747 -87.7083  37.7083         3105.4   14.0   Kentucky
# 2546   2709748 -87.6250  37.7083         2987.3   13.9   Kentucky
# 2547   2705425 -87.8750  37.7917         2599.1   13.5   Kentucky
# 2548   2705427 -87.7083  37.7917         2905.6   14.1   Kentucky
#
# [2549 rows x 6 columns]

# %%
bins = np.arange(0, 20 + 2.5, 2.5)
labels = [f"{bins[i]}–{bins[i+1]}" for i in range(len(bins) - 1)]

df["label_bin"] = pd.cut(df["label"], bins=bins, labels=labels, include_lowest=True)

plt.figure(figsize=(10, 6))

sns.countplot(
    data=df,
    x="label_bin",
    hue="state",
)

plt.xlabel("Label bins")
plt.ylabel("Count")
plt.title("Label Distribution by State")
plt.legend(title="State")
plt.tight_layout()
plt.show()

# %%
bins = np.arange(0, 20 + 2.5, 2.5)
labels = [f"{bins[i]}–{bins[i+1]}" for i in range(len(bins) - 1)]

df["label_bin"] = pd.cut(df["label"], bins=bins, labels=labels, include_lowest=True)

plt.figure(figsize=(10, 6))

sns.countplot(
    data=df,
    x="label_bin",
    hue="state",
)

plt.xlabel("Label bins")
plt.ylabel("Count")
plt.title("Label Distribution by State")
plt.legend(title="State")
plt.tight_layout()
plt.show()

g = sns.FacetGrid(df, col="state", col_wrap=3, height=3)
g.map_dataframe(sns.countplot, x="label_bin")

g.set_axis_labels("Label bins", "Count")
g.set_titles("{col_name}")

for ax in g.axes.flat:
    ax.tick_params(axis="x", rotation=45)

plt.tight_layout()
# plt.show()
